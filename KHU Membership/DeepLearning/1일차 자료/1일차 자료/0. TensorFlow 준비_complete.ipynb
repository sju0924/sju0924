# %% [markdown]
# # TensorFlow 및 Keras

# %%
import tensorflow as tf
from tensorflow import keras

# %%
tf.__version__
# Out:
# '2.5.0'

# %%
keras.__version__
# Out:
# '2.5.0'

# %% [markdown]
# # 파일 업로드

# %% [markdown]
# ## 일반 업로드

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-8f4d1a10-1503-42ee-9fc1-4fbb96be1372" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8f4d1a10-1503-42ee-9fc1-4fbb96be1372">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving lenna.png to lenna (1).png
# ...

# %% [markdown]
# 업로드 결과 체크

# %%
import cv2

img = cv2.imread("lenna.png")
img.shape
# Out:
# (512, 512, 3)

# %% [markdown]
# ## Google Drive 업로드

# %% [markdown]
# ### 방법1. 수동 마운트

# %%
# from google.colab import drive

# %%
# drive.mount('/gdrive', force_remount=True)
# Out:
# Mounted at /gdrive

# %% [markdown]
# ### 방법2. 인터페이스 사용한 마운트

# %% [markdown]
# 1. 혹은 왼쪽의 "폴더" 아이콘 클릭 후,
# 2. 나오는 창에서 맨 오른쪽의 "Google Drive가 있는 폴더 아이콘"을 클릭
#
# 이렇게 하면,

# %%
import cv2
import numpy as np

img: np.ndarray = cv2.imread("/content/drive/MyDrive/강의/경희대 강의/자료/lenna.png")
# img: np.ndarray = cv2.imread("drive/MyDrive/강의/경희대 강의/자료/lenna.png")
img.shape
# Out:
# (512, 512, 3)
